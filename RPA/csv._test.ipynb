# %%
with open('orders.csv','w') as f:
    f.write('고객명,상품명,수량,금액\n')
    f.write('최재진,폴드4,1,800000\n')

# %%
with open('orders.csv','a') as f:
    f.write('제이슨2,버즈프로2,1,200000\n')

# %%
with open('orders.csv','r') as f:
    data=f.readline()
    print(f.readline())
print(data)
# Out:
# 최재진,폴드4,1,800000
#
# 고객명,상품명,수량,금액

# %%
data.rstrip().split(',')
# Out:
# ['고객명', '상품명', '수량', '금액']

# %%
with open('orders.csv','r') as f:
    header=f.readline()

    # [식for변수in리스트]
    datas=[data.rstrip().split(',') for data in f.readlines()]
    datas=f.readlines()
    orders=[]
    for data in datas:
        temp=data.rstrip().split(',')
        orders.append(temp)

print(orders)
# print(datas)
# print(type(datas))
# '고객명,상품명,수량,금액\n'
# ['고객명','상품명','수량','금액']
# Out:
# [['최재진', '폴드4', '1', '800000'],
#  ['제이슨', '버즈프로', '1', '200000'],
#  ['제이슨2', '버즈프로2', '1', '200000']]

# %%
with open('sum.csv','w') as f:
    f.write('연도, 월, 매출\n')

# %%
result=[]
for i in range(1,10):
    with open(f'./csv_files/2017.0{i}.csv','r',encoding='cp949') as f:
        datas=f.readlines()
        for data in datas:
            temp=data.rstrip().split(',')
            result.append(temp)
# for i in range(10,13):
#     with open(f'./csv_files/2017.{i}.csv','r',encoding='cp949') as f:
#         datas=f.readlines()
#         for data in datas:
#             temp=data.rstrip().split(',')
#             result.append(temp)

print(result)
# Out:
# [['수강생명', '수강금액', '상담날짜', '강좌명'], ['배찬우', '900000', '2017.10.10', '파이썬 자동화 강의'], ['조윤장', '820000', '2017.10.11', '파이썬 자동화 강의'], ['김민우', '720000', '2017.10.02', '파이썬 자동화 강의'], ['이은철', '910000', '2017.10.12', '파이썬 자동화 강의'], ['정용운', '900000', '2017.10.09', '파이썬 자동화 강의'], ['윤순규', '920000', '2017.10.06', '파이썬 자동화 강의'], ['이창희', '620000', '2017.10.08', '파이썬 자동화 강의'], ['정택호', '540000', '2017.10.17', '파이썬 자동화 강의'], ['양영주', '230000', '2017.10.02', '파이썬 자동화 강의'], ['권민재', '680000', '2017.10.29', '파이썬 자동화 강의'], ['수강생명', '수강금액', '상담날짜', '강좌명'], ['배찬우', '900000', '2017.10.10', '파이썬 자동화 강의'], ['조윤장', '850000', '2017.10.11', '파이썬 자동화 강의'], ['김민우', '720000', '2017.10.02', '파이썬 자동화 강의'], ['이은철', '890000', '2017.10.12', '파이썬 자동화 강의'], ['정용운', '900000', '2017.10.09', '파이썬 자동화 강의'], ['윤순규', '720000', '2017.10.06', '파이썬 자동화 강의'], ['이창희', '690000', '2017.10.08', '파이썬 자동화 강의'], ['정택호', '230000', '2017.10.17', '파이썬 자동화 강의'], ['양영주', '900000', '2017.10.02', '파이썬 자동화 강의'], ['권민재', '610000', '2017.10.29', '파이썬 자
# ...

# %%
with open('./csv_files/2017.01.csv','r',encoding='cp949') as f:
    datas=f.readlines()
print(datas)
# Out:
# ['수강생명,수강금액,상담날짜,강좌명\n', '배찬우,900000,2017.10.10,파이썬 자동화 강의\n', '조윤장,820000,2017.10.11,파이썬 자동화 강의\n', '김민우,720000,2017.10.02,파이썬 자동화 강의\n', '이은철,910000,2017.10.12,파이썬 자동화 강의\n', '정용운,900000,2017.10.09,파이썬 자동화 강의\n', '윤순규,920000,2017.10.06,파이썬 자동화 강의\n', '이창희,620000,2017.10.08,파이썬 자동화 강의\n', '정택호,540000,2017.10.17,파이썬 자동화 강의\n', '양영주,230000,2017.10.02,파이썬 자동화 강의\n', '권민재,680000,2017.10.29,파이썬 자동화 강의\n']

# %%
# 파일 읽을 때는 encoding 주지 말기
result=[]
for i in range(1,13):
    with open('./csv_files/2017.{0:0>2}.csv'.format(i),'r',encoding='cp949') as f:
        header=f.readline()
        datas=f.readlines()
        result.append(datas)
result
# Out:
# [['배찬우,900000,2017.10.10,파이썬 자동화 강의\n',
#   '조윤장,820000,2017.10.11,파이썬 자동화 강의\n',
#   '김민우,720000,2017.10.02,파이썬 자동화 강의\n',
#   '이은철,910000,2017.10.12,파이썬 자동화 강의\n',
#   '정용운,900000,2017.10.09,파이썬 자동화 강의\n',
#   '윤순규,920000,2017.10.06,파이썬 자동화 강의\n',
#   '이창희,620000,2017.10.08,파이썬 자동화 강의\n',
#   '정택호,540000,2017.10.17,파이썬 자동화 강의\n',
#   '양영주,230000,2017.10.02,파이썬 자동화 강의\n',
#   '권민재,680000,2017.10.29,파이썬 자동화 강의\n'],
#  ['배찬우,900000,2017.10.10,파이썬 자동화 강의\n',
#   '조윤장,850000,2017.10.11,파이썬 자동화 강의\n',
#   '김민우,720000,2017.10.02,파이썬 자동화 강의\n',
#   '이은철,890000,2017.10.12,파이썬 자동화 강의\n',
#   '정용운,900000,2017.10.09,파이썬 자동화 강의\n',
#   '윤순규,720000,2017.10.06,파이썬 자동화 강의\n',
#   '이창희,690000,2017.10.08,파이썬 자동화 강의\n',
#   '정택호,230000,2017.10.17,파이썬 자동화 강의\n',
#   '양영주,900000,2017.10.02,파이썬 자동화 강의\n',
#   '권민재,610000,2017.10.29,파이썬 자동화 강의\n'],
#  ['배찬우,900000,2017.10.10,파이썬 자동화 강의\n',
#   '조윤장,750000,2017.10.11,파이썬 자동화 강의\n',
#   '김민우,720000,2017.10.02,파이썬 자동화 강의\n',
# ...
