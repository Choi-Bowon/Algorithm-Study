# %%
# 이메일 발송을 위한 상수 변수들 설정
SMTP_SERVER='smtp.naver.com'
SMTP_PORT=465
SMTP_USER='cbw1999@naver.com'
SMTP_PASSWORD= open('email_config','r').read().rstrip() # 파일 읽어와서 저장

# %%
from email.mime.multipart import MIMEMultipart 
from email.mime.text import MIMEText

# 편지봉투 만들기
# msg=MIMEMultipart('alternative') # mixed
msg=MIMEMultipart('mixed') # mixed

# 첨부 파일 여부
from email.mime.base import MIMEBase 
from email import encoders
from os.path import basename

# 파일 담을 공간
email_file = MIMEBase('application', 'octet-stream') 

# 파일 읽어오기
with open('./example3/result.xlsx', 'rb') as f:
    file_data = f.read()

# 파일 데이터를 첨부파일에 담아준다.
email_file.set_payload(file_data)
# base64 인코딩형식으로 인코딩
encoders.encode_base64(email_file)

file_name = basename('./example3/result.xlsx') 
email_file.add_header('Content-Disposition', 'attachment', filename=file_name)
msg.attach(email_file)

# 편지 내용
contents="테스트"

msg['From']=SMTP_USER
msg['To']='cbw1999@naver.com'
msg['Subject']='제목제목'

# 편지지를 편지봉토에 담아준다.
text=MIMEText(contents)
msg.attach(text)

# %%
import smtplib

# 이메일 발송을 위한 상수 변수들 설정
SMTP_SERVER='smtp.naver.com'
SMTP_PORT=465
SMTP_USER='cbw1999@naver.com'
SMTP_PASSWORD= open('email_config','r').read().rstrip() # 파일 읽어와서 저장

try:
    # 이메일 전송 서버에 접속
    smtp=smtplib.SMTP_SSL(SMTP_SERVER,SMTP_PORT)
    print('메일 전송 서버 접속 성공')
    smtp.login(SMTP_USER,SMTP_PASSWORD)
    print('로그인 성공 !')
    # sendmail('보내는 사람','받는 사람',msg.as_string())
    smtp.sendmail(SMTP_USER,'cbw1999@naver.com',msg.as_string())
    print('이메일 발송 성공')
    
except Exception as e:
    # 에러 났을 때 실행할 코드
    print('#### 에러 발생 ####')
    print(e)
finally:
    # 에러 여부 상관없이 무조건 실행할 코드
    # smtp 연결 해제
    smtp.close()
    print('파이널리')
# Out:
# 메일 전송 서버 접속 성공
# 로그인 성공 !
# 이메일 발송 성공
# 파이널리

# %%
from email.mime.base import MIMEBase 
from email import encoders
from os.path import basename

# 파일 담을 공간
email_file = MIMEBase('application', 'octet-stream') 

# 파일 읽어오기
with open('./example3/result.xlsx', 'rb') as f:
    file_data = f.read()

# 파일 데이터를 첨부파일에 담아준다.
email_file.set_payload(file_data)
# base64 인코딩형식으로 인코딩
encoders.encode_base64(email_file)

file_name = basename('./example3/result.xlsx') 
email_file.add_header('Content-Disposition', 'attachment', filename=file_name)
msg.attach(email_file)

# %% [markdown]
# ### 실습 4
# - 앞에서 배운 메일 발송 로직을 하나의 함수로 만들기 함수명은 자유롭게 해주세요.
# - def send_mail(params):
#     - code_block

# %%
from email.mime.multipart import MIMEMultipart 
from email.mime.text import MIMEText

from email.mime.base import MIMEBase 
from email import encoders
from os.path import basename

import smtplib

# 이메일 발송을 위한 상수 변수들 설정
SMTP_SERVER='smtp.naver.com'
SMTP_PORT=465
SMTP_USER='cbw1999@naver.com'
SMTP_PASSWORD= open('email_config','r').read().rstrip() # 파일 읽어와서 저장

def send_mail(params):

    msg=MIMEMultipart('alternative')

    # 첨부 파일 여부
    if email_file:
         mag=MIMEMultipart('mixed')

    # 파일 담을 공간
    email_file = MIMEBase('application', 'octet-stream') 

    # 파일 읽어오기
    with open('./example3/result.xlsx', 'rb') as f:
        file_data = f.read()

    # 파일 데이터를 첨부파일에 담아준다.
    email_file.set_payload(file_data)
    # base64 인코딩형식으로 인코딩
    encoders.encode_base64(email_file)

    file_name = basename('./example3/result.xlsx') 
    email_file.add_header('Content-Disposition', 'attachment', filename=file_name)
    msg.attach(email_file)
        
    # 편지 내용
    contents="테스트"

    msg['From']=SMTP_USER
    msg['To']='cbw1999@naver.com'
    msg['Subject']='제목제목'

    # 편지지를 편지봉토에 담아준다.
    text=MIMEText(contents)
    msg.attach(text)

    try:
        # 이메일 전송 서버에 접속
        smtp=smtplib.SMTP_SSL(SMTP_SERVER,SMTP_PORT)
        print('메일 전송 서버 접속 성공')
        smtp.login(SMTP_USER,SMTP_PASSWORD)
        print('로그인 성공 !')
        # sendmail('보내는 사람','받는 사람',msg.as_string())
        smtp.sendmail(SMTP_USER,'cbw1999@naver.com',msg.as_string())
        print('이메일 발송 성공')
        
    except Exception as e:
        # 에러 났을 때 실행할 코드
        print('#### 에러 발생 ####')
        print(e)
    finally:
        # 에러 여부 상관없이 무조건 실행할 코드
        # smtp 연결 해제
        smtp.close()
        print('파이널리')

# %% [markdown]
# ### 실습 5

# %%
# 이메일 발송을 위한 상수 변수들 설정
SMTP_SERVER='smtp.naver.com'
SMTP_PORT=465
SMTP_USER='cbw1999@naver.com'
SMTP_PASSWORD= open('email_config','r').read().rstrip() # 파일 읽어와서 저장

def send_mail(params):

    msg=MIMEMultipart('alternative')

    # 첨부 파일 여부
    if email_file:
         mag=MIMEMultipart('mixed')

    # 파일 담을 공간
    email_file = MIMEBase('application', 'octet-stream') 

    # 파일 읽어오기
    with open('./example3/result.xlsx', 'rb') as f:
        file_data = f.read()

    # 파일 데이터를 첨부파일에 담아준다.
    email_file.set_payload(file_data)
    # base64 인코딩형식으로 인코딩
    encoders.encode_base64(email_file)

    file_name = basename('./example3/result.xlsx') 
    email_file.add_header('Content-Disposition', 'attachment', filename=file_name)
    msg.attach(email_file)
        
    # 편지 내용
    contents="테스트"

    msg['From']=SMTP_USER
    msg['To']='cbw1999@naver.com'
    msg['Subject']='제목제목'

    # 편지지를 편지봉토에 담아준다.
    text=MIMEText(contents)
    msg.attach(text)

    try:
        # 이메일 전송 서버에 접속
        smtp=smtplib.SMTP_SSL(SMTP_SERVER,SMTP_PORT)
        print('메일 전송 서버 접속 성공')
        smtp.login(SMTP_USER,SMTP_PASSWORD)
        print('로그인 성공 !')
        # sendmail('보내는 사람','받는 사람',msg.as_string())
        smtp.sendmail(SMTP_USER,'cbw1999@naver.com',msg.as_string())
        print('이메일 발송 성공')
        
    except Exception as e:
        # 에러 났을 때 실행할 코드
        print('#### 에러 발생 ####')
        print(e)
    finally:
        # 에러 여부 상관없이 무조건 실행할 코드
        # smtp 연결 해제
        smtp.close()
        print('파이널리')

# %%
import openpyxl

new_excel=openpyxl.Workbook()
new_excel.active

sheet=new_excel['Sheet']
