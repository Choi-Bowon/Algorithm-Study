# %%
for i in range(1,11):
    print(f'//*[@id="sp_nws{i}"]')
# Out:
# //*[@id="sp_nws1"]
# //*[@id="sp_nws2"]
# //*[@id="sp_nws3"]
# //*[@id="sp_nws4"]
# //*[@id="sp_nws5"]
# //*[@id="sp_nws6"]
# //*[@id="sp_nws7"]
# //*[@id="sp_nws8"]
# //*[@id="sp_nws9"]
# //*[@id="sp_nws10"]

# %%
for i in range(1,13,3):
    print(f'{i} {i+2}')
# Out:
# 1 3
# 4 6
# 7 9
# 10 12

# %%
for j in range(11,22,1):
    for i in range(1,13,3):
        if i>=10:
            print(f'ds=20{j}.{i}.01&de=20{j}.{i+2}.31')
        else:
            print(f'ds=20{j}.0{i}.01&de=20{j}.0{i+2}.31')
# Out:
# ds=2011.01.01&de=2011.03.31
# ds=2011.04.01&de=2011.06.31
# ds=2011.07.01&de=2011.09.31
# ds=2011.10.01&de=2011.12.31
# ds=2012.01.01&de=2012.03.31
# ds=2012.04.01&de=2012.06.31
# ds=2012.07.01&de=2012.09.31
# ds=2012.10.01&de=2012.12.31
# ds=2013.01.01&de=2013.03.31
# ds=2013.04.01&de=2013.06.31
# ds=2013.07.01&de=2013.09.31
# ds=2013.10.01&de=2013.12.31
# ds=2014.01.01&de=2014.03.31
# ds=2014.04.01&de=2014.06.31
# ds=2014.07.01&de=2014.09.31
# ds=2014.10.01&de=2014.12.31
# ds=2015.01.01&de=2015.03.31
# ds=2015.04.01&de=2015.06.31
# ds=2015.07.01&de=2015.09.31
# ds=2015.10.01&de=2015.12.31
# ds=2016.01.01&de=2016.03.31
# ds=2016.04.01&de=2016.06.31
# ds=2016.07.01&de=2016.09.31
# ds=2016.10.01&de=2016.12.31
# ds=2017.01.01&de=2017.03.31
# ds=2017.04.01&de=2017.06.31
# ds=2017.07.01&de=2017.09.31
# ds=2017.10.01&de=2017.12.31
# ds=2018.01.01&de=2018.03.31
# ds=2018.04.01&de=2018.06.31
# ds=2018.07.01&de=2018.09.31
# ds=2018.10.01&de=2018.12.31
# ds=2019.01.01&de=2019.03.31
# ...

# %%
for j in range(21,22,1): # 수정
    for i in range(1,13,3):
        if i>=10:
            urls=f'https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=20{j}.{i}.01&de=20{j}.{i+2}.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom20{j}{i}01to20{j}{i+2}31&is_sug_officeid=0&start=' # 11 -> 3992로 바꿔주기
            for url in urls:
                try:
                    print(url)
                    # yield scrapy.Request(url=url, callback = self.parse)
                except:
                    break
        else:
            urls=f'https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=20{j}.0{i}.01&de=20{j}.0{i+2}.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom20{j}0{i}01to20{j}0{i+2}31&is_sug_officeid=0&start=' # 11 -> 3992로 바꿔주기
            for url in urls:
                try:
                    print(url)
                    # yield scrapy.Request(url=url, callback = self.parse)
                except:
                    break
# Out:
# h
# t
# t
# p
# s
# :
# /
# /
# s
# e
# a
# r
# c
# h
# .
# n
# a
# v
# e
# r
# .
# c
# o
# m
# /
# s
# e
# a
# r
# c
# h
# .
# n
# a
# v
# e
# r
# ?
# w
# h
# e
# r
# e
# =
# n
# e
# w
# s
# &
# q
# u
# e
# r
# y
# =
# %
# E
# A
# %
# B
# 8
# %
# 8
# 8
# %
# E
# B
# %
# A
# 6
# %
# A
# C
# &
# s
# m
# =
# t
# a
# b
# _
# o
# p
# t
# &
# s
# o
# r
# t
# =
# 2
# &
# p
# h
# o
# t
# o
# =
# 0
# &
# f
# i
# e
# l
# d
# =
# 0
# &
# p
# d
# =
# 3
# &
# d
# s
# =
# 2
# 0
# 2
# 1
# .
# 0
# 1
# .
# 0
# 1
# &
# d
# e
# =
# 2
# 0
# 2
# 1
# .
# 0
# 3
# .
# 3
# 1
# &
# d
# o
# c
# i
# d
# =
# &
# r
# e
# l
# a
# t
# e
# d
# =
# 0
# &
# m
# y
# n
# e
# w
# s
# =
# 1
# &
# o
# f
# f
# i
# c
# e
# _
# t
# y
# p
# e
# =
# 1
# &
# o
# f
# f
# i
# c
# e
# _
# s
# e
# c
# t
# i
# o
# n
# _
# c
# o
# d
# e
# =
# 2
# &
# n
# e
# w
# s
# _
# o
# f
# f
# i
# c
# e
# _
# c
# h
# e
# c
# k
# e
# d
# =
# 1
# 0
# 0
# 1
# &
# n
# s
# o
# =
# s
# o
# %
# 3
# A
# r
# %
# 2
# C
# p
# %
# 3
# A
# f
# r
# o
# m
# 2
# ...

# %%
for j in range(21,22,1): # 수정
    for i in range(1,13,3):
        if i>=10:
            urls=f'https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=20{j}.{i}.01&de=20{j}.{i+2}.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom20{j}{i}01to20{j}{i+2}31&is_sug_officeid=0&start=' # 11 -> 3992로 바꿔주기
            urls=[urls+str(k) for k in range(1, 11,10)]
            for url in urls:
                print(url)
        else:
            urls=f'https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=20{j}.0{i}.01&de=20{j}.0{i+2}.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom20{j}0{i}01to20{j}0{i+2}31&is_sug_officeid=0&start=' # 11 -> 3992로 바꿔주기
                      
            urls=[urls+str(k) for k in range(1, 11,10)]
            for url in urls:
                print(url)
# Out:
# https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=2021.01.01&de=2021.03.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom20210101to20210331&is_sug_officeid=0&start=1
# https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=2021.04.01&de=2021.06.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom20210401to20210631&is_sug_officeid=0&start=1
# https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=2021.07.01&de=2021.09.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom20210701to20210931&is_sug_officeid=0&start=1
# ...

# %%
for j in range(21,22,1): # 수정
    for i in range(1,13,3):
        for k in range(1, 21,10):
            urls=f'https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=20{j}.{i}.01&de=20{j}.{i+2}.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom20{j}{i}01to20{j}{i+2}31&is_sug_officeid=0&start={k}' # 11 -> 3992로 바꿔주기
            print(urls)
# Out:
# https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=2021.1.01&de=2021.3.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom2021101to2021331&is_sug_officeid=0&start=1
# https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=2021.1.01&de=2021.3.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom2021101to2021331&is_sug_officeid=0&start=11
# https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds=2021.4.01&de=2021.6.31&docid=&related=0&mynews=1&office_type=1&office_section_code=2&news_office_checked=1001&nso=so%3Ar%2Cp%3Afrom2021401to2021631&is_sug_officeid=0&start=1
# ...

# %%
result = [f'//*[@id="sp_nws{i}"]' for i in range(1,11)]
result
# Out:
# ['//*[@id="sp_nws1"]',
#  '//*[@id="sp_nws2"]',
#  '//*[@id="sp_nws3"]',
#  '//*[@id="sp_nws4"]',
#  '//*[@id="sp_nws5"]',
#  '//*[@id="sp_nws6"]',
#  '//*[@id="sp_nws7"]',
#  '//*[@id="sp_nws8"]',
#  '//*[@id="sp_nws9"]',
#  '//*[@id="sp_nws10"]']

# %%
[f'//*[@id="sp_nws{i}"]' for i in range(1,4)]
# Out:
# ['//*[@id="sp_nws1"]', '//*[@id="sp_nws2"]', '//*[@id="sp_nws3"]']
